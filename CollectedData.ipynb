# %% [markdown]
# <a href="https://colab.research.google.com/github/sachini86/MyResearch/blob/main/CollectedData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_4241/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_5058/3329394316.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive', force_remount=True)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

base = '/content/drive/MyDrive'

# List your grade folders — adjust names if they differ
folders = ['Alba', 'c4', 'c5', 'c5-special']
views = ['top', 'bottom', 'left', 'right', 'cross']

for grade in folders:
    total = 0
    for view in views:
        path = f'{base}/{grade}/{view}'
        if os.path.exists(path):
            count = len(os.listdir(path))
            total += count
        else:
            print(f"⚠️  NOT FOUND: {path}")
    print(f"{grade}: {total} images total")
# Out:
# ⚠️  NOT FOUND: /content/drive/MyDrive/Alba/top
# ⚠️  NOT FOUND: /content/drive/MyDrive/Alba/bottom
# ⚠️  NOT FOUND: /content/drive/MyDrive/Alba/left
# ⚠️  NOT FOUND: /content/drive/MyDrive/Alba/right
# ⚠️  NOT FOUND: /content/drive/MyDrive/Alba/cross
# Alba: 0 images total
# ⚠️  NOT FOUND: /content/drive/MyDrive/c4/top
# ⚠️  NOT FOUND: /content/drive/MyDrive/c4/bottom
# ⚠️  NOT FOUND: /content/drive/MyDrive/c4/left
# ⚠️  NOT FOUND: /content/drive/MyDrive/c4/right
# ⚠️  NOT FOUND: /content/drive/MyDrive/c4/cross
# c4: 0 images total
# ⚠️  NOT FOUND: /content/drive/MyDrive/c5/top
# ⚠️  NOT FOUND: /content/drive/MyDrive/c5/bottom
# ⚠️  NOT FOUND: /content/drive/MyDrive/c5/left
# ⚠️  NOT FOUND: /content/drive/MyDrive/c5/right
# ⚠️  NOT FOUND: /content/drive/MyDrive/c5/cross
# c5: 0 images total
# ⚠️  NOT FOUND: /content/drive/MyDrive/c5-special/top
# ⚠️  NOT FOUND: /content/drive/MyDrive/c5-special/bottom
# ⚠️  NOT FOUND: /content/drive/MyDrive/c5-special/left
# ...

# %%
import os

# See exactly what's in your MyDrive
print("Root folders in MyDrive:")
for item in os.listdir('/content/drive/MyDrive'):
    print(f"  '{item}'")
# Out:
# Root folders in MyDrive:
#   'ict.pdf'
#   'icon.png'
#   'IMG20210812133116.jpg'
#   'IMG20210930105627 (1).jpg'
#   'IMG20210930105627.jpg'
#   'Dushyantha Sir Live 2021 12 13 (1).pdf'
#   '1655708935262.jpg'
#   'https:  www.fac.txt'
#   'VID_20220812_122721.mp4'
#   '1660457835302.jpg'
#   '1662990165613.jpg'
#   '20APP4948 (1).pdf'
#   'IMG_20230111_191630.jpg'
#   'Analytical chemistry.pdf'
#   'Assignment 2 (12201).pdf'
#   'note (1).zip'
#   'notes'
#   'note.zip'
#   '1675430496742.jpg'
#   'Letter.gdoc'
#   'Prototyping presentation.gslides'
#   'Untitled presentation (1).gslides'
#   'Untitled document (8).gdoc'
#   'Untitled spreadsheet (9).gsheet'
#   'Untitled spreadsheet (8).gsheet'
#   'Untitled spreadsheet (7).gsheet'
#   'Untitled spreadsheet (6).gsheet'
#   'Untitled presentation.gslides'
#   'Untitled document (7).gdoc'
#   'subject.gdoc'
#   'sachini 3.docx'
#   'sachini 3.gdoc'
#   'Report.gdoc'
#   'Untitled document (6).gdoc'
#   'Document1.gdoc'
# ...

# %%
import os

base = '/content/drive/MyDrive'

# List your grade folders — adjust names if they differ
folders = ['Alba', 'C4', 'C5', 'C5-special']
views = ['Top', 'Bottom', 'Left', 'Right', 'Cross']

for grade in folders:
    total = 0
    for view in views:
        path = f'{base}/{grade}/{view}'
        if os.path.exists(path):
            count = len(os.listdir(path))
            total += count
        else:
            print(f"⚠️  NOT FOUND: {path}")
    print(f"{grade}: {total} images total")
# Out:
# Alba: 250 images total
# C4: 95 images total
# C5: 115 images total
# C5-special: 160 images total

# %%
import shutil

src_base = '/content/drive/MyDrive'
dst_base = '/content/cinnamon_dataset'

grade_map = {
    'Albha': 'Alba',       # rename to clean label
    'C4': 'C4',
    'C5': 'C5',
    'C5_special': 'C5_special'
}

views = ['Top', 'Bottom', 'Left', 'Right', 'Cross']

for src_grade, dst_grade in grade_map.items():
    dst_folder = f'{dst_base}/{dst_grade}'
    os.makedirs(dst_folder, exist_ok=True)

    count = 0
    for view in views:
        src_folder = f'{src_base}/{src_grade}/{view}'
        if not os.path.exists(src_folder):
            print(f"Skipping (not found): {src_folder}")
            continue
        for fname in os.listdir(src_folder):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                # Add view name to filename to avoid duplicates
                new_name = f'{view}_{fname}'
                shutil.copy(
                    os.path.join(src_folder, fname),
                    os.path.join(dst_folder, new_name)
                )
                count += 1
    print(f"✅ {dst_grade}: {count} images copied")
# Out:
# Skipping (not found): /content/drive/MyDrive/Albha/Top
# Skipping (not found): /content/drive/MyDrive/Albha/Bottom
# Skipping (not found): /content/drive/MyDrive/Albha/Left
# Skipping (not found): /content/drive/MyDrive/Albha/Right
# Skipping (not found): /content/drive/MyDrive/Albha/Cross
# ✅ Alba: 0 images copied
# ✅ C4: 0 images copied
# ✅ C5: 0 images copied
# Skipping (not found): /content/drive/MyDrive/C5_special/Top
# Skipping (not found): /content/drive/MyDrive/C5_special/Bottom
# Skipping (not found): /content/drive/MyDrive/C5_special/Left
# Skipping (not found): /content/drive/MyDrive/C5_special/Right
# Skipping (not found): /content/drive/MyDrive/C5_special/Cross
# ✅ C5_special: 0 images copied

# %%
# Check exact folder names and what's inside
base = '/content/drive/MyDrive'

for item in os.listdir(base):
    print(f"FOLDER: '{item}'")
    # Check if it looks like a cinnamon folder
    if any(x in item.lower() for x in ['alb', 'c4', 'c5']):
        folder_path = f'{base}/{item}'
        for sub in os.listdir(folder_path):
            print(f"   SUBFOLDER: '{sub}'")
            sub_path = f'{folder_path}/{sub}'
            if os.path.isdir(sub_path):
                files = os.listdir(sub_path)
                if files:
                    print(f"      First file: '{files[0]}'")
# Out:
# FOLDER: 'ict.pdf'
# FOLDER: 'icon.png'
# FOLDER: 'IMG20210812133116.jpg'
# FOLDER: 'IMG20210930105627 (1).jpg'
# FOLDER: 'IMG20210930105627.jpg'
# FOLDER: 'Dushyantha Sir Live 2021 12 13 (1).pdf'
# FOLDER: '1655708935262.jpg'
# FOLDER: 'https:  www.fac.txt'
# FOLDER: 'VID_20220812_122721.mp4'
# FOLDER: '1660457835302.jpg'
# FOLDER: '1662990165613.jpg'
# FOLDER: '20APP4948 (1).pdf'
# FOLDER: 'IMG_20230111_191630.jpg'
# FOLDER: 'Analytical chemistry.pdf'
# FOLDER: 'Assignment 2 (12201).pdf'
# FOLDER: 'note (1).zip'
# FOLDER: 'notes'
# FOLDER: 'note.zip'
# FOLDER: '1675430496742.jpg'
# FOLDER: 'Letter.gdoc'
# FOLDER: 'Prototyping presentation.gslides'
# FOLDER: 'Untitled presentation (1).gslides'
# FOLDER: 'Untitled document (8).gdoc'
# FOLDER: 'Untitled spreadsheet (9).gsheet'
# FOLDER: 'Untitled spreadsheet (8).gsheet'
# FOLDER: 'Untitled spreadsheet (7).gsheet'
# FOLDER: 'Untitled spreadsheet (6).gsheet'
# FOLDER: 'Untitled presentation.gslides'
# ...

# %%
# STEP 1: Install HEIC support
# !pip install pillow-heif -q

from pillow_heif import register_heif_opener
from PIL import Image
register_heif_opener()
import os, shutil

src_base = '/content/drive/MyDrive'
dst_base = '/content/cinnamon_dataset'

# EXACT names from your Drive
grade_map = {
    'Alba':       'alba',
    'C4':         'c4',
    'C5':         'c5',
    'C5-special': 'c5_special'
}

views = ['Top', 'Bottom', 'Left', 'Right', 'Cross']

for src_grade, dst_grade in grade_map.items():
    dst_folder = f'{dst_base}/{dst_grade}'
    os.makedirs(dst_folder, exist_ok=True)
    count = 0

    for view in views:
        src_folder = f'{src_base}/{src_grade}/{view}'
        if not os.path.exists(src_folder):
            print(f"⚠️  Not found: {src_folder}")
            continue

        for fname in os.listdir(src_folder):
            src_path = os.path.join(src_folder, fname)

            if fname.lower().endswith('.heic'):
                # Convert HEIC → JPG
                try:
                    img = Image.open(src_path).convert('RGB')
                    new_name = f'{view}_{fname[:-5]}.jpg'
                    img.save(os.path.join(dst_folder, new_name), 'JPEG', quality=95)
                    count += 1
                except Exception as e:
                    print(f"Failed to convert {fname}: {e}")

            elif fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                # Copy JPG directly
                new_name = f'{view}_{fname}'
                shutil.copy(src_path, os.path.join(dst_folder, new_name))
                count += 1

    print(f"✅ {dst_grade}: {count} images ready")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 90.4 MB/s eta 0:00:00
# ✅ alba: 250 images ready
# ✅ c4: 95 images ready
# ✅ c5: 115 images ready
# ✅ c5_special: 160 images ready

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0, MobileNetV2, ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import warnings
warnings.filterwarnings('ignore')
print("✅ All libraries loaded")
# Out:
# ✅ All libraries loaded

# %%
DATASET_PATH = '/content/cinnamon_dataset'
IMG_SIZE = (224, 224)
BATCH_SIZE = 16
CLASSES = ['alba', 'c4', 'c5', 'c5_special']

# First check what folders actually exist in the dataset
print("Folders found in dataset:")
for f in sorted(os.listdir(DATASET_PATH)):
    print(f"  '{f}'")
# Out:
# Folders found in dataset:
#   'Alba'
#   'C4'
#   'C5'
#   'C5_special'
#   'alba'
#   'c4'
#   'c5'
#   'c5_special'

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.15,
    height_shift_range=0.15,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.7, 1.3],
    shear_range=0.1,
    fill_mode='reflect',
    validation_split=0.2
)

val_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASSES,          # ← explicitly list only your 4 classes
    subset='training',
    shuffle=True,
    seed=42
)

val_generator = val_datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASSES,          # ← same here
    subset='validation',
    shuffle=False,
    seed=42
)

print(f"Training samples:   {train_generator.samples}")
print(f"Validation samples: {val_generator.samples}")
print(f"Classes: {train_generator.class_indices}")
# Out:
# Found 496 images belonging to 4 classes.
# Found 124 images belonging to 4 classes.
# Training samples:   496
# Validation samples: 124
# Classes: {'alba': 0, 'c4': 1, 'c5': 2, 'c5_special': 3}

# %%
# Cell 3 - Recalculate class weights
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights = dict(enumerate(class_weights_array))
print("Class weights:")
for i, cls in enumerate(CLASSES):
    print(f"  {cls}: {class_weights_array[i]:.3f}")
# Out:
# Class weights:
#   alba: 0.620
#   c4: 1.632
#   c5: 1.348
#   c5_special: 0.969

# %%
# Build model
base = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224,224,3))
base.trainable = False

x = GlobalAveragePooling2D()(base.output)
x = BatchNormalization()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(4, activation='softmax')(x)

effnet_model = Model(base.input, output)
effnet_model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=10,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                      patience=5, min_lr=1e-7, verbose=1)
]

print("📌 Phase 1: Training top layers...")
history1 = effnet_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20,
    class_weight=class_weights,
    callbacks=callbacks,
    verbose=1
)

print("\n📌 Phase 2: Fine-tuning...")
base.trainable = True
for layer in base.layers[:-30]:
    layer.trainable = False

effnet_model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history2 = effnet_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20,
    class_weight=class_weights,
    callbacks=callbacks,
    verbose=1
)
print("✅ EfficientNetB0 done!")
# Out:
# 📌 Phase 1: Training top layers...
# Epoch 1/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 127s 3s/step - accuracy: 0.2419 - loss: 1.8880 - val_accuracy: 0.2581 - val_loss: 1.4094 - learning_rate: 0.0010
# Epoch 2/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.2379 - loss: 2.0811 - val_accuracy: 0.1532 - val_loss: 1.4336 - learning_rate: 0.0010
# Epoch 3/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.2500 - loss: 1.8575 - val_accuracy: 0.2581 - val_loss: 1.3989 - learning_rate: 0.0010
# Epoch 4/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.2056 - loss: 1.8919 - val_accuracy: 0.4032 - val_loss: 1.3694 - learning_rate: 0.0010
# Epoch 5/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.2520 - loss: 1.7783 - val_accuracy: 0.4032 - val_loss: 1.3688 - learning_rate: 0.0010
# Epoch 6/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.2298 - loss: 1.7168 - val_accuracy: 0.4032 - val_loss: 1.3723 - learning_rate: 0.0010
# Epoch 7/20
# ...

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# First check your images are loading correctly
sample_batch, sample_labels = next(iter(train_generator))
print(f"Batch shape: {sample_batch.shape}")
print(f"Pixel range: min={sample_batch.min():.2f}, max={sample_batch.max():.2f}")
print(f"Label sample: {sample_labels[0]}")

# Visualize a few images to confirm they look correct
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2, 4, figsize=(14, 6))
for i, ax in enumerate(axes.flat):
    ax.imshow(sample_batch[i])
    ax.set_title(CLASSES[np.argmax(sample_labels[i])])
    ax.axis('off')
plt.suptitle('Sample Training Images — Check These Look Correct', fontweight='bold')
plt.tight_layout()
plt.savefig('/content/sample_images.png', dpi=100)
plt.show()
# Out:
# Batch shape: (16, 224, 224, 3)
# Pixel range: min=0.00, max=1.00
# Label sample: [0. 1. 0. 0.]

# %%
base_mob = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224,224,3))
base_mob.trainable = False
x = GlobalAveragePooling2D()(base_mob.output)
x = BatchNormalization()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(4, activation='softmax')(x)
mob_model = Model(base_mob.input, output)
mob_model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
                  loss='categorical_crossentropy', metrics=['accuracy'])

history_mob1 = mob_model.fit(
    train_generator, validation_data=val_generator,
    epochs=20, class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

base_mob.trainable = True
for layer in base_mob.layers[:-20]:
    layer.trainable = False
mob_model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
                  loss='categorical_crossentropy', metrics=['accuracy'])

history_mob2 = mob_model.fit(
    train_generator, validation_data=val_generator,
    epochs=15, class_weight=class_weights,
    callbacks=callbacks, verbose=1
)
print("✅ MobileNetV2 done!")
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - accuracy: 0.6190 - loss: 1.1160 - val_accuracy: 0.7419 - val_loss: 0.7400 - learning_rate: 0.0010
# Epoch 2/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.7823 - loss: 0.6767 - val_accuracy: 0.8226 - val_loss: 0.5129 - learning_rate: 0.0010
# Epoch 3/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.8508 - loss: 0.4943 - val_accuracy: 0.8306 - val_loss: 0.4747 - learning_rate: 0.0010
# Epoch 4/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.8226 - loss: 0.5420 - val_accuracy: 0.8226 - val_loss: 0.5079 - learning_rate: 0.0010
# Epoch 5/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.8226 - loss: 0.5191 - val_accuracy: 0.9274 - val_loss: 0.2846 - learning_rate: 0.0010
# Epoch 6/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.8105 - loss: 0.5830 - val_accuracy: 0.9274 - val_loss: 0.2571 - learning_rate: 0.0010
# Epoch 7/20
# ...

# %%
base_res = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
base_res.trainable = False
x = GlobalAveragePooling2D()(base_res.output)
x = BatchNormalization()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(4, activation='softmax')(x)
res_model = Model(base_res.input, output)
res_model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
                  loss='categorical_crossentropy', metrics=['accuracy'])

history_res1 = res_model.fit(
    train_generator, validation_data=val_generator,
    epochs=20, class_weight=class_weights,
    callbacks=callbacks, verbose=1
)

base_res.trainable = True
for layer in base_res.layers[:-30]:
    layer.trainable = False
res_model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
                  loss='categorical_crossentropy', metrics=['accuracy'])

history_res2 = res_model.fit(
    train_generator, validation_data=val_generator,
    epochs=15, class_weight=class_weights,
    callbacks=callbacks, verbose=1
)
print("✅ ResNet50 done!")
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Epoch 1/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 95s 3s/step - accuracy: 0.5282 - loss: 1.1570 - val_accuracy: 0.4032 - val_loss: 1.3956 - learning_rate: 0.0010
# Epoch 2/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5827 - loss: 1.0128 - val_accuracy: 0.4758 - val_loss: 1.4154 - learning_rate: 0.0010
# Epoch 3/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.6573 - loss: 0.9351 - val_accuracy: 0.4032 - val_loss: 1.2969 - learning_rate: 0.0010
# Epoch 4/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 74s 2s/step - accuracy: 0.6431 - loss: 0.9115 - val_accuracy: 0.5161 - val_loss: 1.2856 - learning_rate: 0.0010
# Epoch 5/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6498 - loss: 0.9140
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.6552 - loss: 0.8646 - val_accuracy: 0.4032 - val_loss: 1.2305 - learning_rate: 0.0010
# Epoch 6/20
# ...

# %%
def evaluate_model(model, generator, model_name):
    generator.reset()
    y_pred = np.argmax(model.predict(generator, verbose=0), axis=1)
    y_true = generator.classes
    acc = np.mean(y_pred == y_true)
    print(f"\n{'='*50}")
    print(f"RESULTS: {model_name}  —  Accuracy: {acc*100:.2f}%")
    print(f"{'='*50}")
    print(classification_report(y_true, y_pred, target_names=CLASSES, digits=4))
    return y_pred, y_true, acc

pred_eff, true_eff, acc_eff = evaluate_model(effnet_model, val_generator, "EfficientNetB0")
pred_mob, true_mob, acc_mob = evaluate_model(mob_model,    val_generator, "MobileNetV2")
pred_res, true_res, acc_res = evaluate_model(res_model,    val_generator, "ResNet50")

print("\n" + "="*45)
print("FINAL COMPARISON")
print("="*45)
print(f"EfficientNetB0 : {acc_eff*100:.2f}%")
print(f"MobileNetV2    : {acc_mob*100:.2f}%")
print(f"ResNet50       : {acc_res*100:.2f}%")
# Out:
# ...
# RESULTS: EfficientNetB0  —  Accuracy: 40.32%
# ...
#               precision    recall  f1-score   support
#
#         alba     0.4032    1.0000    0.5747        50
#           c4     0.0000    0.0000    0.0000        19
#           c5     0.0000    0.0000    0.0000        23
#   c5_special     0.0000    0.0000    0.0000        32
#
#     accuracy                         0.4032       124
#    macro avg     0.1008    0.2500    0.1437       124
# weighted avg     0.1626    0.4032    0.2317       124
#
#
# ...
# RESULTS: MobileNetV2  —  Accuracy: 87.10%
# ...
#               precision    recall  f1-score   support
#
#         alba     1.0000    1.0000    1.0000        50
#           c4     1.0000    0.6842    0.8125        19
#           c5     0.6061    0.8696    0.7143        23
#   c5_special     0.8929    0.7812    0.8333        32
#
#     accuracy                         0.8710       124
#    macro avg     0.8747    0.8338    0.8400       124
# weighted avg     0.8993    0.8710    0.8753       124
# ...

# %%
# Confusion matrices
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, y_true, y_pred, name in zip(
    axes,
    [true_eff, true_mob, true_res],
    [pred_eff, pred_mob, pred_res],
    ['EfficientNetB0', 'MobileNetV2', 'ResNet50']
):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=CLASSES, yticklabels=CLASSES, ax=ax)
    ax.set_title(f'{name}', fontweight='bold')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.suptitle('Confusion Matrices — Cinnamon Grade Classification',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('/content/confusion_matrices.png', dpi=150, bbox_inches='tight')
plt.show()
print("✅ Saved: confusion_matrices.png")

# Training curves for best model (EfficientNetB0)
acc_all = history1.history['accuracy'] + history2.history['accuracy']
val_acc_all = history1.history['val_accuracy'] + history2.history['val_accuracy']

plt.figure(figsize=(8, 5))
plt.plot(acc_all, label='Train Accuracy', color='steelblue')
plt.plot(val_acc_all, label='Val Accuracy', color='orange')
plt.axvline(len(history1.history['accuracy'])-1, color='red',
            linestyle='--', alpha=0.6, label='Fine-tune start')
plt.title('EfficientNetB0 — Training Accuracy', fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('/content/training_curves.png', dpi=150)
plt.show()
print("✅ Saved: training_curves.png")
# Out:
# ✅ Saved: confusion_matrices.png
# ✅ Saved: training_curves.png

# %%
import cv2

def show_gradcam(model, img_path, true_label):
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    img_array = tf.keras.preprocessing.image.img_to_array(img) / 255.0
    img_input = np.expand_dims(img_array, axis=0)

    # Find last conv layer
    last_conv = [l.name for l in model.layers
             if hasattr(l, 'output_shape') and len(l.output_shape) == 4][-1]
    grad_model = tf.keras.models.Model(
        model.inputs, [model.get_layer(last_conv).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_out, preds = grad_model(img_input)
        pred_class = tf.argmax(preds[0])
        loss = preds[:, pred_class]
    grads = tape.gradient(loss, conv_out)
    pooled = tf.reduce_mean(grads, axis=(0,1,2))
    cam = conv_out[0] @ pooled[..., tf.newaxis]
    cam = tf.squeeze(cam).numpy()
    cam = np.maximum(cam, 0)
    cam = cam / cam.max() if cam.max() > 0 else cam

    img_orig = np.uint8(img_array * 255)
    heatmap = cv2.resize(cam, (224, 224))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)
    overlay = cv2.addWeighted(img_orig, 0.6, heatmap, 0.4, 0)

    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(img_orig)
    axes[0].set_title(f'Original — {true_label}', fontweight='bold')
    axes[0].axis('off')
    axes[1].imshow(overlay)
    axes[1].set_title(f'Grad-CAM — Predicted: {CLASSES[pred_class.numpy()]}', fontweight='bold')
    axes[1].axis('off')
    plt.tight_layout()
    plt.savefig(f'/content/gradcam_{true_label}.png', dpi=150)
    plt.show()

for grade in CLASSES:
    folder = f'{DATASET_PATH}/{grade}'
    sample = os.path.join(folder, os.listdir(folder)[0])
    show_gradcam(effnet_model, sample, grade)
    print(f"✅ Grad-CAM saved for {grade}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_8464/502223596.py in <cell line: 0>()
#      44     folder = f'{DATASET_PATH}/{grade}'
#      45     sample = os.path.join(folder, os.listdir(folder)[0])
# ---> 46     show_gradcam(effnet_model, sample, grade)
#      47     print(f"✅ Grad-CAM saved for {grade}")
#
# /tmp/ipykernel_8464/502223596.py in show_gradcam(model, img_path, true_label)
#       7
#       8     # Find last conv layer
# ----> 9     last_conv = [l.name for l in model.layers
#      10              if hasattr(l, 'output_shape') and len(l.output_shape) == 4][-1]
#      11     grad_model = tf.keras.models.Model(
#
# IndexError: list index out of range
